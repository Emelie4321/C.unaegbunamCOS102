# %%
Step-by-Step Algorithm
Start
Input the first name (e.g., Name1) and their age (Age1).
Input the second name (e.g., Name2) and their age (Age2).
Create a temporary variable called Temp.
Assign the value of Age1 to Temp (Temp = Age1).
Assign the value of Age2 to Age1 (Age1 = Age2).
Assign the value of Temp back to Age2 (Age2 = Temp).
Output the names with their new swapped ages.
Stop
